# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.multioutput import MultiOutputRegressor

# Load the dataset
df = pd.read_csv('your_dataset.csv')

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[['A', 'B', 'C', 'D', 'E', 'F']], 
                                                    df[['HDT_0.455©', 'UTS(Mpa)', 'Modulus(Gpa)', 
                                                        'EAB%', 'Viscosity_75C(cp)', 'R value']], 
                                                    test_size=0.3, random_state=42)

# Train separate linear regression models for each target feature
model_hdt = LinearRegression()
model_hdt.fit(X_train, y_train['HDT_0.455©'])

model_uts = LinearRegression()
model_uts.fit(X_train, y_train['UTS(Mpa)'])

model_mod = LinearRegression()
model_mod.fit(X_train, y_train['Modulus(Gpa)'])

model_eab = LinearRegression()
model_eab.fit(X_train, y_train['EAB%'])

model_vis = LinearRegression()
model_vis.fit(X_train, y_train['Viscosity_75C(cp)'])

model_r = LinearRegression()
model_r.fit(X_train, y_train['R value'])












# Combine the models into a single multi-output regression model
multi_model = MultiOutputRegressor(estimator=LinearRegression())
multi_model.fit(X_train, y_train)

# Evaluate the performance of the multi-output regression model on the testing set
y_pred = multi_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('MSE:', mse)
print('RMSE:', rmse)
print('R-squared:', r2)

# Make predictions for new values of A, B, C, D, E, and F
new_data = pd.DataFrame({'A': [0.5], 'B': [50], 'C': [5], 'D': [5], 'E': [15], 'F': [12]})
predictions = multi_model.predict(new_data)
print(predictions)
